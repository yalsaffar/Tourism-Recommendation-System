# %%
from flights import  flights_reco
from userdata import users
from data_structure import data_strcture
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
# Out:
# /home/yousif/Desktop/All/IE_Third_Year_2/RS/Project_All/Tourism-Recommendation-System/lib/models/Flights.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   df['bags_price'] = grouped_bag['bags_price'].apply(lambda x: x.fillna(x.dropna().iloc[0]) if x.isnull().values.any() else x)
# /home/yousif/Desktop/All/IE_Third_Year_2/RS/Project_All/Tourism-Recommendation-System/lib/models/Flights.py:13: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   df['availability'] = grouped_avl['availability'].apply(lambda x: x.fillna(x.dropna().iloc[0]) if x.isnull().values.any() else x)

# %%
#titles,indices, cosine_sim, df = model_computations()
titles = pd.read_csv('../datasets/data_files/titles.csv')
df = pd.read_csv('../datasets/data_files/df.csv')
df2 = df.reset_index()
titles = pd.Series(df2['Description'])
indices = pd.Series(df2.index, index = df2['Description'])
cosine_sim = np.load('../datasets/data_files/cosine_sim.npy')

# %%
flights_reco('TIA','ALC','ALC',titles,indices, cosine_sim,df)
# Out:
#     flyFrom flyTo  price cityFrom   cityTo countryFrom  distance  duration  \
# 0       TIA   AGP    212   Tirana   Málaga     Albania   2151.60    142500
# 1       TIA   AGP    253   Tirana   Málaga     Albania   2151.60    118800
# 2       TIA   AGP    265   Tirana   Málaga     Albania   2151.60    155100
# 3       TIA   AGP    266   Tirana   Málaga     Albania   2151.60    215700
# 4       TIA   AGP    280   Tirana   Málaga     Albania   2151.60    136200
# ..      ...   ...    ...      ...      ...         ...       ...       ...
# 711     TIA   MLN    978   Tirana  Melilla     Albania   2086.93     66300
# 712     TIA   MLN    992   Tirana  Melilla     Albania   2086.93     62100
# 713     TIA   MLN   1220   Tirana  Melilla     Albania   2086.93     63000
# 714     TIA   MLN   2141   Tirana  Melilla     Albania   2086.93     65400
# 715     TIA   MLN   2183   Tirana  Melilla     Albania   2086.93     63000
#
#          local_departure    category  \
# 0    2023-02-28 17:15:00       Beach
# 1    2023-02-28 12:20:00       Beach
# 2    2023-02-28 20:55:00       Beach
# 3    2023-02-28 20:55:00       Beach
# 4    2023-02-28 19:00:00       Beach
# ..                   ...         ...
# 711  2023-02-28 20:00:00  Historical
# 712  2023-02-28 16:00:00  Historical
# 713  2023-02-28 20:55:00  Historical
# 714  2023-02-28 15:45:00  Historical
# 715  2023-02-28 15:45:00  Historical
#
#                                            Description
# 0    coastal city southern coast spain known medite...
# 1    coastal city southern coast spain known medite...
# 2    coastal city southern coast spain known medite...
# 3    coastal city southern coast spain known medite...
# 4    coastal city southern coast spain known medite...
# ..                                                 ...
# 711  spanish enclave northern coast africa melilla ...
# 712  spanish enclave northern coast africa melilla ...
# 713  spanish enclave northern coast africa melilla ...
# 714  spanish enclave northern coast africa melilla ...
# 715  spanish enclave northern coast africa melilla ...
#
# [677 rows x 11 columns]

# %%
_, user_df, pool_df = data_strcture()

# %%
def model(location, previous,best):
        
    recos = flights_reco(location,previous,best,titles,indices, cosine_sim,df)
    return recos.head(50)

# %%
price_ranges = {'PriceLvl_1': [0, 100], 'PriceLvl_2': [100, 200], 'PriceLvl_3': [200, 300], 'PriceLvl_4': [300, 400], 
                'PriceLvl_5': [400, 500], 'PriceLvl_6': [500, 600], 'PriceLvl_7': [600, 700], 'PriceLvl_8': [700, 800], 
                'PriceLvl_9': [800, 900], 'PriceLvl_10': [900, 1000], 'PriceLvl_15': [1000, 1500], 
                'PriceLvl_20': [1500, 2000], 'PriceLvl_30': [2000, 3000], 'PriceLvl_40': [3000, 4000]}

time_cols_dict = {
    'EarlyMorning': [4, 7],
    'Morning': [7, 12],
    'Noon': [12, 16],
    'Afternoon': [16, 19],
    'Evening': [19, 23],
    'Night': [0, 4]
}

cities_dict = {'Tirana': 'TIA',
 'Graz': 'GRZ',
 'Innsbruck': 'INN',
 'Brussels': 'CRL',
 'Paphos': 'PFO',
 'Tallinn': 'TLL',
 'Helsinki': 'HEL',
 'Turku': 'TKU',
 'Lille': 'LIL',
 'Lyon': 'LYS',
 'Paris': 'ORY',
 'Kutaisi': 'KUT',
 'Dresden': 'DRS',
 'Leipzig': 'LEJ',
 'Munich': 'MUC',
 'Athens': 'ATH',
 'Chania': 'CHQ',
 'Santorini': 'JTR',
 'Thessaloniki': 'SKG',
 'Knock, County Mayo': 'NOC',
 'County Kerry': 'KIR',
 'Cagliari': 'CAG',
 'Catania': 'CTA',
 'Naples': 'NAP',
 'Olbia': 'OLB',
 'Trapani': 'TPS',
 'Venice': 'TSF',
 'Kaunas': 'KUN',
 'Vilnius': 'VNO',
 'Oslo': 'TRF',
 'Stavanger': 'SVG',
 'Warsaw': 'WMI',
 'Timișoara': 'TSR',
 'Niš': 'INI',
 'Málaga': 'AGP',
 'Alicante': 'ALC',
 'Almería': 'LEI',
 'Asturias': 'OVD',
 'Bilbao': 'BIO',
 'Barcelona': 'BCN',
 'Badajoz': 'BJZ',
 'Béziers': 'BZR',
 'Brindisi': 'BDS',
 'Donostia / San Sebastián': 'EAS',
 'Fuerteventura': 'FUE',
 'Girona': 'GRO',
 'Granada': 'GRX',
 'Ibiza': 'IBZ',
 'Jerez de la Frontera': 'XRY',
 'A Coruña': 'LCG',
 'Lanzarote': 'ACE',
 'Madrid': 'MAD',
 'Agadir': 'AGA',
 'Menorca': 'MAH',
 'Melilla': 'MLN',
 'Palma, Majorca': 'PMI',
 'Pamplona': 'PNA',
 'Santander': 'SDR',
 'Seville': 'SVQ',
 'Tenerife': 'TFS',
 'Valencia': 'VLC',
 'Valladolid': 'VLL',
 'Vigo': 'VGO',
 'Vitoria-Gasteiz': 'VIT',
 'Valverde': 'VDE',
 'Zaragoza': 'ZAZ',
 'Santiago de Compostela': 'SCQ'}

# %%
previous = 'ALC'

for i in range(2):
    location = input()

    city_names = list(set(df['cityTo'])) # Replace with your desired cities
    city_counts = user_df.filter(items=city_names).sum().sort_values(ascending=False)

    highest_city = city_counts.index[0]
    second_highest_city = city_counts.index[1]
    third_highest_city = city_counts.index[2]

    price_max_col = user_df.filter(like='PriceLvl_').idxmax(axis=1)
    activity_max_col = user_df.filter(['Beach', 'Nature', 'Cultural', 'Historical', 'Adventurous']).idxmax(axis=1)
    time_max_col = user_df.filter(['EarlyMorning', 'Morning', 'Noon', 'Afternoon', 'Evening', 'Night']).idxmax(axis=1)
    
    if i != 3:
        reco = model(location,previous,cities_dict[highest_city])
    elif i == 6:
        reco = model(location,previous,cities_dict[third_highest_city])
    else:
        reco = model(location,previous,cities_dict[second_highest_city])
    reco['local_departure'] = pd.to_datetime(reco['local_departure'])

    reco_filtered = reco[(reco['price'] >= price_ranges[str(price_max_col[0])][0]) & (reco['price'] <= price_ranges[str(price_max_col[0])][1])]
    reco_filtered2 = reco_filtered[(reco_filtered['local_departure'].dt.hour >= time_cols_dict[str(time_max_col[0])][0]) & (reco_filtered['local_departure'].dt.hour <= time_cols_dict[str(time_max_col[0])][1])]
    reco_filtered3 = reco_filtered2[reco_filtered2['category']== str(activity_max_col[0])]

    reco_others = reco[(reco['price'] < price_ranges[str(price_max_col[0])][0]) | (reco['price'] > price_ranges[str(price_max_col[0])][1])]
    reco_others2 = reco_filtered[(reco_filtered['local_departure'].dt.hour < time_cols_dict[str(time_max_col[0])][0]) | (reco_filtered['local_departure'].dt.hour > time_cols_dict[str(time_max_col[0])][1])]
    reco_others3 = reco_filtered2[reco_filtered2['category']!= str(activity_max_col[0])]

    reco_final = pd.concat([reco_filtered,reco_filtered2,reco_filtered3, reco_others,reco_others2,reco_others3])
    reco_final = reco_final.drop_duplicates(keep='first')

    previous = reco_final['flyTo'].iloc[0]

    print(reco_final.head(1))
    print("Do you like this offer: (yes:1, no:0)")
    indicator = input()
    
    
    pool_df, user_df = users(0 ,df, user_df, pool_df, reco_final['cityTo'].iloc[0], reco_final['category'].iloc[0], reco_final['price'].iloc[0], str(reco_final['local_departure'].iloc[0]), indicator)
# Out:
#    flyFrom flyTo  price cityFrom   cityTo countryFrom  distance  duration  \
# 95     TIA   LEI    332   Tirana  Almería     Albania   1968.22    188700
#
#        local_departure category  \
# 95 2023-02-28 17:15:00    Beach
#
#                                           Description
# 95  city southeastern coast spain known beautiful ...
# Do you like this offer: (yes:1, no:0)
# 1

# %%
reco['local_departure'] = pd.to_datetime(reco['local_departure'])

reco_filtered = reco[(reco['price'] >= price_ranges[str(price_max_col[0])][0]) & (reco['price'] <= price_ranges[str(price_max_col[0])][1])]
reco_filtered2 = reco_filtered[(reco_filtered['local_departure'].dt.hour >= time_cols_dict[str(time_max_col[0])][0]) & (reco_filtered['local_departure'].dt.hour <= time_cols_dict[str(time_max_col[0])][1])]
reco_filtered3 = reco_filtered2[reco_filtered2['category']== str(activity_max_col[0])]

reco_others = reco[(reco['price'] < price_ranges[str(price_max_col[0])][0]) | (reco['price'] > price_ranges[str(price_max_col[0])][1])]
reco_others2 = reco_filtered[(reco_filtered['local_departure'].dt.hour < time_cols_dict[str(time_max_col[0])][0]) | (reco_filtered['local_departure'].dt.hour > time_cols_dict[str(time_max_col[0])][1])]
reco_others3 = reco_filtered2[reco_filtered2['category']!= str(activity_max_col[0])]

reco_final = pd.concat([reco_filtered,reco_filtered2,reco_filtered3, reco_others,reco_others2,reco_others3])
reco_final = reco_final.drop_duplicates(keep='first')

reco_final
# Out:
#     flyFrom flyTo  price cityFrom    cityTo countryFrom  distance  duration  \
# 56      TIA   ALC    184   Tirana  Alicante     Albania   1763.50    171000
# 57      TIA   ALC    196   Tirana  Alicante     Albania   1763.50    143700
# 58      TIA   ALC    230   Tirana  Alicante     Albania   1763.50    144000
# 59      TIA   ALC    239   Tirana  Alicante     Albania   1763.50    129600
# 60      TIA   ALC    253   Tirana  Alicante     Albania   1763.50    104400
# 61      TIA   ALC    282   Tirana  Alicante     Albania   1763.50    138900
# 62      TIA   ALC    294   Tirana  Alicante     Albania   1763.50     87600
# 63      TIA   ALC    294   Tirana  Alicante     Albania   1763.50    100800
# 64      TIA   ALC    330   Tirana  Alicante     Albania   1763.50     97500
# 65      TIA   ALC    335   Tirana  Alicante     Albania   1763.50     79500
# 66      TIA   ALC    339   Tirana  Alicante     Albania   1763.50     81600
# 67      TIA   ALC    353   Tirana  Alicante     Albania   1763.50     63300
# 68      TIA   ALC    359   Tirana  Alicante     Albania   1763.50     97500
# 69      TIA   ALC    361   Tirana  Alicante     Albania   1763.50     76800
# 70      TIA   ALC    366   Tirana  Alicante     Albania   1763.50     74100
# 71      TIA   ALC    369   Tirana  Alicante     Albania   1763.50     63300
# 72      TIA   ALC    383   Tirana  Alicante     Albania   1763.50     69900
# 73      TIA   ALC    385   Tirana  Alicante     Albania   1763.50     69900
# 74      TIA   ALC    389   Tirana  Alicante     Albania   1763.50     79800
# 75      TIA   ALC    408   Tirana  Alicante     Albania   1763.50     34500
# 76      TIA   ALC    425   Tirana  Alicante     Albania   1763.50     31500
# 77      TIA   ALC    447   Tirana  Alicante     Albania   1763.50     30600
# 78      TIA   ALC    474   Tirana  Alicante     Albania   1763.50     31800
# 79      TIA   ALC    482   Tirana  Alicante     Albania   1763.50     60600
# 80      TIA   ALC    512   Tirana  Alicante     Albania   1763.50     84000
# 81      TIA   ALC    537   Tirana  Alicante     Albania   1763.50     84000
# 82      TIA   ALC    539   Tirana  Alicante     Albania   1763.50     83100
# 83      TIA   ALC    544   Tirana  Alicante     Albania   1763.50     78600
# 84      TIA   ALC    621   Tirana  Alicante     Albania   1763.50     78900
# 85      TIA   ALC    630   Tirana  Alicante     Albania   1763.50     73200
# 86      TIA   ALC    631   Tirana  Alicante     Albania   1763.50     62100
# 87      TIA   ALC    689   Tirana  Alicante     Albania   1763.50     63900
# 88      TIA   ALC    707   Tirana  Alicante     Albania   1763.50     60300
# 89      TIA   ALC    761   Tirana  Alicante     Albania   1763.50     72300
# 90      TIA   ALC    839   Tirana  Alicante     Albania   1763.50     68100
# 91      TIA   ALC    884   Tirana  Alicante     Albania   1763.50     69000
# 92      TIA   ALC    901   Tirana  Alicante     Albania   1763.50     59700
# 93      TIA   ALC    957   Tirana  Alicante     Albania   1763.50     59700
# 94      TIA   ALC   1020   Tirana  Alicante     Albania   1763.50     59100
# 132     TIA   OVD    219   Tirana  Asturias     Albania   2119.06    198600
# 133     TIA   OVD    227   Tirana  Asturias     Albania   2119.06    186600
# 134     TIA   OVD    231   Tirana  Asturias     Albania   2119.06    177900
# 135     TIA   OVD    238   Tirana  Asturias     Albania   2119.06    165900
# 136     TIA   OVD    240   Tirana  Asturias     Albania   2119.06     79500
# 137     TIA   OVD    244   Tirana  Asturias     Albania   2119.06    135000
# 138     TIA   OVD    249   Tirana  Asturias     Albania   2119.06    132300
# 139     TIA   OVD    317   Tirana  Asturias     Albania   2119.06     81600
# 140     TIA   OVD    322   Tirana  Asturias     Albania   2119.06    105300
# 141     TIA   OVD    322   Tirana  Asturias     Albania   2119.06    169200
# 142     TIA   OVD    329   Tirana  Asturias     Albania   2119.06     92100
#
#         local_departure category  \
# 56  2023-02-28 11:30:00    Beach
# 57  2023-02-28 17:15:00    Beach
# 58  2023-02-28 19:00:00    Beach
# 59  2023-02-28 20:55:00    Beach
# 60  2023-02-28 12:20:00    Beach
# 61  2023-02-28 19:00:00    Beach
# 62  2023-02-28 20:55:00    Beach
# 63  2023-02-28 12:20:00    Beach
# 64  2023-02-28 20:55:00    Beach
# 65  2023-02-28 11:30:00    Beach
# 66  2023-02-28 20:55:00    Beach
# 67  2023-02-28 16:00:00    Beach
# 68  2023-02-28 12:20:00    Beach
# 69  2023-02-28 19:00:00    Beach
# 70  2023-02-28 12:20:00    Beach
# 71  2023-02-28 16:00:00    Beach
# 72  2023-02-28 20:55:00    Beach
# 73  2023-02-28 20:55:00    Beach
# 74  2023-02-28 20:55:00    Beach
# 75  2023-02-28 13:20:00    Beach
# 76  2023-02-28 15:45:00    Beach
# 77  2023-02-28 16:00:00    Beach
# 78  2023-02-28 14:10:00    Beach
# 79  2023-02-28 18:00:00    Beach
# 80  2023-02-28 15:45:00    Beach
# 81  2023-02-28 15:45:00    Beach
# 82  2023-02-28 19:00:00    Beach
# 83  2023-02-28 20:55:00    Beach
# 84  2023-02-28 17:30:00    Beach
# 85  2023-02-28 20:55:00    Beach
# 86  2023-02-28 20:55:00    Beach
# 87  2023-02-28 17:45:00    Beach
# 88  2023-02-28 17:45:00    Beach
# 89  2023-02-28 19:00:00    Beach
# 90  2023-02-28 17:30:00    Beach
# 91  2023-02-28 19:00:00    Beach
# 92  2023-02-28 17:15:00    Beach
# 93  2023-02-28 17:15:00    Beach
# 94  2023-02-28 20:00:00    Beach
# 132 2023-02-28 11:30:00   Nature
# 133 2023-02-28 11:30:00   Nature
# 134 2023-02-28 17:15:00   Nature
# 135 2023-02-28 17:15:00   Nature
# 136 2023-02-28 12:20:00   Nature
# 137 2023-02-28 20:55:00   Nature
# 138 2023-02-28 20:55:00   Nature
# 139 2023-02-28 17:15:00   Nature
# 140 2023-02-28 19:00:00   Nature
# 141 2023-02-28 19:00:00   Nature
# 142 2023-02-28 20:55:00   Nature
#
#                                            Description
# 56   city eastern coast spain known long stretch sa...
# 57   city eastern coast spain known long stretch sa...
# 58   city eastern coast spain known long stretch sa...
# 59   city eastern coast spain known long stretch sa...
# 60   city eastern coast spain known long stretch sa...
# 61   city eastern coast spain known long stretch sa...
# 62   city eastern coast spain known long stretch sa...
# 63   city eastern coast spain known long stretch sa...
# 64   city eastern coast spain known long stretch sa...
# 65   city eastern coast spain known long stretch sa...
# 66   city eastern coast spain known long stretch sa...
# 67   city eastern coast spain known long stretch sa...
# 68   city eastern coast spain known long stretch sa...
# 69   city eastern coast spain known long stretch sa...
# 70   city eastern coast spain known long stretch sa...
# 71   city eastern coast spain known long stretch sa...
# 72   city eastern coast spain known long stretch sa...
# 73   city eastern coast spain known long stretch sa...
# 74   city eastern coast spain known long stretch sa...
# 75   city eastern coast spain known long stretch sa...
# 76   city eastern coast spain known long stretch sa...
# 77   city eastern coast spain known long stretch sa...
# 78   city eastern coast spain known long stretch sa...
# 79   city eastern coast spain known long stretch sa...
# 80   city eastern coast spain known long stretch sa...
# 81   city eastern coast spain known long stretch sa...
# 82   city eastern coast spain known long stretch sa...
# 83   city eastern coast spain known long stretch sa...
# 84   city eastern coast spain known long stretch sa...
# 85   city eastern coast spain known long stretch sa...
# 86   city eastern coast spain known long stretch sa...
# 87   city eastern coast spain known long stretch sa...
# 88   city eastern coast spain known long stretch sa...
# 89   city eastern coast spain known long stretch sa...
# 90   city eastern coast spain known long stretch sa...
# 91   city eastern coast spain known long stretch sa...
# 92   city eastern coast spain known long stretch sa...
# 93   city eastern coast spain known long stretch sa...
# 94   city eastern coast spain known long stretch sa...
# 132  region northwestern spain known lush landscape...
# 133  region northwestern spain known lush landscape...
# 134  region northwestern spain known lush landscape...
# 135  region northwestern spain known lush landscape...
# 136  region northwestern spain known lush landscape...
# 137  region northwestern spain known lush landscape...
# 138  region northwestern spain known lush landscape...
# 139  region northwestern spain known lush landscape...
# 140  region northwestern spain known lush landscape...
# 141  region northwestern spain known lush landscape...
# 142  region northwestern spain known lush landscape...

# %%
reco.dtypes
# Out:
# flyFrom                    object
# flyTo                      object
# price                       int64
# cityFrom                   object
# cityTo                     object
# countryFrom                object
# distance                  float64
# duration                    int64
# local_departure    datetime64[ns]
# category                   object
# Description                object
# dtype: object

# %%
reco
# Out:
#     flyFrom flyTo  price cityFrom    cityTo countryFrom  distance  duration  \
# 56      TIA   ALC    184   Tirana  Alicante     Albania   1763.50    171000
# 57      TIA   ALC    196   Tirana  Alicante     Albania   1763.50    143700
# 58      TIA   ALC    230   Tirana  Alicante     Albania   1763.50    144000
# 59      TIA   ALC    239   Tirana  Alicante     Albania   1763.50    129600
# 60      TIA   ALC    253   Tirana  Alicante     Albania   1763.50    104400
# 61      TIA   ALC    282   Tirana  Alicante     Albania   1763.50    138900
# 62      TIA   ALC    294   Tirana  Alicante     Albania   1763.50     87600
# 63      TIA   ALC    294   Tirana  Alicante     Albania   1763.50    100800
# 64      TIA   ALC    330   Tirana  Alicante     Albania   1763.50     97500
# 65      TIA   ALC    335   Tirana  Alicante     Albania   1763.50     79500
# 66      TIA   ALC    339   Tirana  Alicante     Albania   1763.50     81600
# 67      TIA   ALC    353   Tirana  Alicante     Albania   1763.50     63300
# 68      TIA   ALC    359   Tirana  Alicante     Albania   1763.50     97500
# 69      TIA   ALC    361   Tirana  Alicante     Albania   1763.50     76800
# 70      TIA   ALC    366   Tirana  Alicante     Albania   1763.50     74100
# 71      TIA   ALC    369   Tirana  Alicante     Albania   1763.50     63300
# 72      TIA   ALC    383   Tirana  Alicante     Albania   1763.50     69900
# 73      TIA   ALC    385   Tirana  Alicante     Albania   1763.50     69900
# 74      TIA   ALC    389   Tirana  Alicante     Albania   1763.50     79800
# 75      TIA   ALC    408   Tirana  Alicante     Albania   1763.50     34500
# 76      TIA   ALC    425   Tirana  Alicante     Albania   1763.50     31500
# 77      TIA   ALC    447   Tirana  Alicante     Albania   1763.50     30600
# 78      TIA   ALC    474   Tirana  Alicante     Albania   1763.50     31800
# 79      TIA   ALC    482   Tirana  Alicante     Albania   1763.50     60600
# 80      TIA   ALC    512   Tirana  Alicante     Albania   1763.50     84000
# 81      TIA   ALC    537   Tirana  Alicante     Albania   1763.50     84000
# 82      TIA   ALC    539   Tirana  Alicante     Albania   1763.50     83100
# 83      TIA   ALC    544   Tirana  Alicante     Albania   1763.50     78600
# 84      TIA   ALC    621   Tirana  Alicante     Albania   1763.50     78900
# 85      TIA   ALC    630   Tirana  Alicante     Albania   1763.50     73200
# 86      TIA   ALC    631   Tirana  Alicante     Albania   1763.50     62100
# 87      TIA   ALC    689   Tirana  Alicante     Albania   1763.50     63900
# 88      TIA   ALC    707   Tirana  Alicante     Albania   1763.50     60300
# 89      TIA   ALC    761   Tirana  Alicante     Albania   1763.50     72300
# 90      TIA   ALC    839   Tirana  Alicante     Albania   1763.50     68100
# 91      TIA   ALC    884   Tirana  Alicante     Albania   1763.50     69000
# 92      TIA   ALC    901   Tirana  Alicante     Albania   1763.50     59700
# 93      TIA   ALC    957   Tirana  Alicante     Albania   1763.50     59700
# 94      TIA   ALC   1020   Tirana  Alicante     Albania   1763.50     59100
# 132     TIA   OVD    219   Tirana  Asturias     Albania   2119.06    198600
# 133     TIA   OVD    227   Tirana  Asturias     Albania   2119.06    186600
# 134     TIA   OVD    231   Tirana  Asturias     Albania   2119.06    177900
# 135     TIA   OVD    238   Tirana  Asturias     Albania   2119.06    165900
# 136     TIA   OVD    240   Tirana  Asturias     Albania   2119.06     79500
# 137     TIA   OVD    244   Tirana  Asturias     Albania   2119.06    135000
# 138     TIA   OVD    249   Tirana  Asturias     Albania   2119.06    132300
# 139     TIA   OVD    317   Tirana  Asturias     Albania   2119.06     81600
# 140     TIA   OVD    322   Tirana  Asturias     Albania   2119.06    105300
# 141     TIA   OVD    322   Tirana  Asturias     Albania   2119.06    169200
# 142     TIA   OVD    329   Tirana  Asturias     Albania   2119.06     92100
#
#         local_departure category  \
# 56  2023-02-28 11:30:00    Beach
# 57  2023-02-28 17:15:00    Beach
# 58  2023-02-28 19:00:00    Beach
# 59  2023-02-28 20:55:00    Beach
# 60  2023-02-28 12:20:00    Beach
# 61  2023-02-28 19:00:00    Beach
# 62  2023-02-28 20:55:00    Beach
# 63  2023-02-28 12:20:00    Beach
# 64  2023-02-28 20:55:00    Beach
# 65  2023-02-28 11:30:00    Beach
# 66  2023-02-28 20:55:00    Beach
# 67  2023-02-28 16:00:00    Beach
# 68  2023-02-28 12:20:00    Beach
# 69  2023-02-28 19:00:00    Beach
# 70  2023-02-28 12:20:00    Beach
# 71  2023-02-28 16:00:00    Beach
# 72  2023-02-28 20:55:00    Beach
# 73  2023-02-28 20:55:00    Beach
# 74  2023-02-28 20:55:00    Beach
# 75  2023-02-28 13:20:00    Beach
# 76  2023-02-28 15:45:00    Beach
# 77  2023-02-28 16:00:00    Beach
# 78  2023-02-28 14:10:00    Beach
# 79  2023-02-28 18:00:00    Beach
# 80  2023-02-28 15:45:00    Beach
# 81  2023-02-28 15:45:00    Beach
# 82  2023-02-28 19:00:00    Beach
# 83  2023-02-28 20:55:00    Beach
# 84  2023-02-28 17:30:00    Beach
# 85  2023-02-28 20:55:00    Beach
# 86  2023-02-28 20:55:00    Beach
# 87  2023-02-28 17:45:00    Beach
# 88  2023-02-28 17:45:00    Beach
# 89  2023-02-28 19:00:00    Beach
# 90  2023-02-28 17:30:00    Beach
# 91  2023-02-28 19:00:00    Beach
# 92  2023-02-28 17:15:00    Beach
# 93  2023-02-28 17:15:00    Beach
# 94  2023-02-28 20:00:00    Beach
# 132 2023-02-28 11:30:00   Nature
# 133 2023-02-28 11:30:00   Nature
# 134 2023-02-28 17:15:00   Nature
# 135 2023-02-28 17:15:00   Nature
# 136 2023-02-28 12:20:00   Nature
# 137 2023-02-28 20:55:00   Nature
# 138 2023-02-28 20:55:00   Nature
# 139 2023-02-28 17:15:00   Nature
# 140 2023-02-28 19:00:00   Nature
# 141 2023-02-28 19:00:00   Nature
# 142 2023-02-28 20:55:00   Nature
#
#                                            Description
# 56   city eastern coast spain known long stretch sa...
# 57   city eastern coast spain known long stretch sa...
# 58   city eastern coast spain known long stretch sa...
# 59   city eastern coast spain known long stretch sa...
# 60   city eastern coast spain known long stretch sa...
# 61   city eastern coast spain known long stretch sa...
# 62   city eastern coast spain known long stretch sa...
# 63   city eastern coast spain known long stretch sa...
# 64   city eastern coast spain known long stretch sa...
# 65   city eastern coast spain known long stretch sa...
# 66   city eastern coast spain known long stretch sa...
# 67   city eastern coast spain known long stretch sa...
# 68   city eastern coast spain known long stretch sa...
# 69   city eastern coast spain known long stretch sa...
# 70   city eastern coast spain known long stretch sa...
# 71   city eastern coast spain known long stretch sa...
# 72   city eastern coast spain known long stretch sa...
# 73   city eastern coast spain known long stretch sa...
# 74   city eastern coast spain known long stretch sa...
# 75   city eastern coast spain known long stretch sa...
# 76   city eastern coast spain known long stretch sa...
# 77   city eastern coast spain known long stretch sa...
# 78   city eastern coast spain known long stretch sa...
# 79   city eastern coast spain known long stretch sa...
# 80   city eastern coast spain known long stretch sa...
# 81   city eastern coast spain known long stretch sa...
# 82   city eastern coast spain known long stretch sa...
# 83   city eastern coast spain known long stretch sa...
# 84   city eastern coast spain known long stretch sa...
# 85   city eastern coast spain known long stretch sa...
# 86   city eastern coast spain known long stretch sa...
# 87   city eastern coast spain known long stretch sa...
# 88   city eastern coast spain known long stretch sa...
# 89   city eastern coast spain known long stretch sa...
# 90   city eastern coast spain known long stretch sa...
# 91   city eastern coast spain known long stretch sa...
# 92   city eastern coast spain known long stretch sa...
# 93   city eastern coast spain known long stretch sa...
# 94   city eastern coast spain known long stretch sa...
# 132  region northwestern spain known lush landscape...
# 133  region northwestern spain known lush landscape...
# 134  region northwestern spain known lush landscape...
# 135  region northwestern spain known lush landscape...
# 136  region northwestern spain known lush landscape...
# 137  region northwestern spain known lush landscape...
# 138  region northwestern spain known lush landscape...
# 139  region northwestern spain known lush landscape...
# 140  region northwestern spain known lush landscape...
# 141  region northwestern spain known lush landscape...
# 142  region northwestern spain known lush landscape...

# %%
# Print the results
print('Max price column:', price_max_col[0])
print('Max activity column:', activity_max_col[0])
print('Max time column:', time_max_col[0])
# Out:
# Max price column: PriceLvl_1
# Max activity column: Beach
# Max time column: EarlyMorning
